# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.image import imread

# %%
brain = imread('brain2.jpg')

# %%
mask = imread('mask0.jpg')

# %%
plt.imshow(mask);
plt.colorbar();

# %%
plt.hist(mask.ravel(), bins=100, range=(0.0, 256), fc='k', ec='k');

# %%
plt.imshow(brain);
plt.colorbar();

# %%
binarized = 255 * (mask > 1)

# %%
np.unique(binarized)
# Out:
# array([0, 1])

# %%
plt.imshow(binarized, cmap='hot')

# %%
plt.hist(binarized.ravel(), bins=100, range=(0.0, 256), fc='k', ec='k');
